# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
! ls
# Out:
# gdrive	sample_data

# %%
# %cd  gdrive/MyDrive/'Colab Notebooks'/Git_clone_python
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Git_clone_python

# %%
! ls
# Out:
# Python

# %%
! git clone https://github.com/vilquer/Python
# Out:
# Cloning into 'Python'...
# remote: Enumerating objects: 1384, done.
# remote: Counting objects: 100% (206/206), done.
# remote: Compressing objects: 100% (157/157), done.
# remote: Total 1384 (delta 71), reused 168 (delta 38), pack-reused 1178
# Receiving objects: 100% (1384/1384), 132.72 MiB | 14.41 MiB/s, done.
# Resolving deltas: 100% (416/416), done.
# Checking out files: 100% (862/862), done.

# %%
# %cd Python
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Git_clone_python/Python

# %%
! git pull
# Out:
# Already up to date.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/MyDrive/'Colab Notebooks'/Git_clone_python/Python
! git pull
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/MyDrive/Colab Notebooks/Git_clone_python/Python'
# /
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %cd /content/gdrive/MyDrive/'Colab Notebooks'/Git_clone_python/Python
# !ls
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Git_clone_python/Python
# '01 - PowerShell'	   '10 - Arquivados'    teste.py
# '02 - Cursos'		    button.py	       'teste se esta instalado.ipynb'
# '04 - Seguindo Tutoriais'   button_support.py   Untitled.ipynb
# '05 - Machine Learning'     README.md
# '06 - Dicas'		    stop.gif

# %%
# %cd //
# Out:
# /

# %%
# !git add -p
# Out:
# No changes.

# %%
# !git commit
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@588d258d88b5.(none)')
