# %%
 1 > 2
# Out:
# False

# %%
2 == 2
# Out:
# True

# %%
False == True
# Out:
# False

# %%
not(False) == True
# Out:
# True

# %%
(True and False) == True
# Out:
# False

# %%
(True or False) == True
# Out:
# True

# %%
3 >= 5
# Out:
# False

# %%
3 >= 5 or 3 >= 3
# Out:
# True
