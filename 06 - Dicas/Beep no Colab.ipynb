# %%
from google.colab import output
def beep():
  # Clipes de audio Gratuitos "http://soundbible.com/"
  output.eval_js('new Audio("http://soundbible.com/grab.php?id=583&type=mp3").play()')

# %%
# Chamando a função beep
beep()
