# %% [markdown]
# # Operadores

# %% [markdown]
# ##### Matemáticos

# %%
x = 3
y = 2

# %%
#soma
print('Soma - ', x + y)
print('Subtração - ', x - y)
print('Multiplicaçao - ', x * y)
print('Divisão - ', x / y)
print('Módulo - ', x % y)
print('Inteiro da divisão - ', x // y)
print('Exponenciação - ', x ** y)
# Out:
# Soma -  5
# Subtração -  1
# Multiplicaçao -  6
# Divisão -  1.5
# Módulo -  1
# Inteiro da divisão -  1
# Exponenciação -  9
