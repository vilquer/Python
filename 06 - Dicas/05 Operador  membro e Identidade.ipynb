# %%
"Casa" in "Minha Casa"
# Out:
# True

# %%
# Case Sensitive - Maiúsculas e Minúsculas importam
"Casa" in "minha casa"
# Out:
# False

# %%
a = 257
b = a
a is b
# Out:
# True

# %%
a = 257
b = 257
a is b
# Out:
# False

# %%
print(id(a))
print(id(b))
# Out:
# 140706141797936
# 140706141797712
