# %% [markdown]
# ### Comentários
# É ignorado pelo interpretador

# %%
# Use o símbolo "# "
1+1 # Pode ser colocado ao lado da instrução.
# Out:
# 2

# %% [markdown]
# A pesar de não constar na PEP8 alguns progrmadores fazem comentarios
# em bloco com três aspas simpes ou duplas, normalmente para não perder a
# identação de um bloco de progrmação que será revisto ou que não quer rodar
# naquele momento.
# Não é indicado pois se trata de formato reservado para docstrings

# %%
""" comentario de uma parte que devo revisar depois
for i in range(10):
  print(i)
"""
1+1
# Out:
# 2
