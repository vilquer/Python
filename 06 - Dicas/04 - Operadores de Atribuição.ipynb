# %%
variavel = 5
variavel
# Out:
# 5

# %%
variavel += 1
variavel
# Out:
# 6

# %%
variavel -= 1
variavel
# Out:
# 5

# %%
variavel *= 5
variavel
# Out:
# 25

# %%
variavel /= 3
variavel
# Out:
# 8.333333333333334

# %%
variavel //= 1
variavel
# Out:
# 8.0

# %%
variavel **= 2
variavel
# Out:
# 64.0

# %%
variavel %= 7
variavel
# Out:
# 1.0
