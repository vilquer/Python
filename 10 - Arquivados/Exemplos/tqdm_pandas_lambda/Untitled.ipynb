# %%
#conda install -c conda-forge tqdm
#conda install -c conda-forge ipywidgets

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra

import pandas as pd
# pandas defaults
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("input"))
# Out:
# ['datasets_1474_2639_IMDB-Movie-Data.csv']

# %%
df = pd.read_csv("input/datasets_1474_2639_IMDB-Movie-Data.csv")

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016                123
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# 1     7.0  485820              126.46       65.0
# 2     7.3  157606              138.12       62.0
# 3     7.2   60545              270.32       59.0
# 4     6.2  393727              325.02       40.0

# %%
#renaming some cols
df.rename(columns = {'Revenue (Millions)':'Rev_M','Runtime (Minutes)':'Runtime_min'},inplace=True)

# %%
df['AvgRating'] = (df['Rating'] + df['Metascore']/10)/2

# %%
def custom_rating(genre,rating):
    if 'Thriller' in genre:
        return min(10,rating+1)
    elif 'Comedy' in genre:
        return max(0,rating-1)
    else:
        return rating
        
df['CustomRating'] = df.apply(lambda x: custom_rating(x['Genre'],x['Rating']),axis=1)

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime_min  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014          121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012          124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016          117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016          108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016          123
#
#    Rating   Votes   Rev_M  Metascore  AvgRating  CustomRating
# 0     8.1  757074  333.13       76.0       7.85           8.1
# 1     7.0  485820  126.46       65.0       6.75           7.0
# 2     7.3  157606  138.12       62.0       6.75           8.3
# 3     7.2   60545  270.32       59.0       6.55           6.2
# 4     6.2  393727  325.02       40.0       5.10           6.2

# %%
# Single condition: dataframe with all movies rated greater than 8
df_gt_8 = df[df['Rating']>8]

df_gt_8.head()
# Out:
#     Rank                    Title                    Genre  \
# 0      1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
# 6      7               La La Land       Comedy,Drama,Music
# 16    17            Hacksaw Ridge  Biography,Drama,History
# 18    19                     Lion          Biography,Drama
# 26    27  Bahubali: The Beginning   Action,Adventure,Drama
#
#                                           Description         Director  \
# 0   A group of intergalactic criminals are forced ...       James Gunn
# 6   A jazz pianist falls for an aspiring actress i...  Damien Chazelle
# 16  WWII American Army Medic Desmond T. Doss, who ...       Mel Gibson
# 18  A five-year-old Indian boy gets lost on the st...      Garth Davis
# 26  In ancient India, an adventurous and daring ma...   S.S. Rajamouli
#
#                                                Actors  Year  Runtime_min  \
# 0   Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014          121
# 6   Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....  2016          128
# 16  Andrew Garfield, Sam Worthington, Luke Bracey,...  2016          139
# 18  Dev Patel, Nicole Kidman, Rooney Mara, Sunny P...  2016          118
# 26  Prabhas, Rana Daggubati, Anushka Shetty,Tamann...  2015          159
#
#     Rating   Votes   Rev_M  Metascore  AvgRating  CustomRating
# 0      8.1  757074  333.13       76.0       7.85           8.1
# 6      8.3  258682  151.06       93.0       8.80           7.3
# 16     8.2  211760   67.12       71.0       7.65           8.2
# 18     8.1  102061   51.69       69.0       7.50           8.1
# 26     8.3   76193    6.50        NaN        NaN           8.3

# %%
# Multiple conditions: AND - dataframe with all movies rated greater than 8 and having more than 100000 votes

And_df = df[(df['Rating']>8) & (df['Votes']>100000)]

And_df.head()
# Out:
#     Rank                    Title                    Genre  \
# 0      1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
# 6      7               La La Land       Comedy,Drama,Music
# 16    17            Hacksaw Ridge  Biography,Drama,History
# 18    19                     Lion          Biography,Drama
# 36    37             Interstellar   Adventure,Drama,Sci-Fi
#
#                                           Description           Director  \
# 0   A group of intergalactic criminals are forced ...         James Gunn
# 6   A jazz pianist falls for an aspiring actress i...    Damien Chazelle
# 16  WWII American Army Medic Desmond T. Doss, who ...         Mel Gibson
# 18  A five-year-old Indian boy gets lost on the st...        Garth Davis
# 36  A team of explorers travel through a wormhole ...  Christopher Nolan
#
#                                                Actors  Year  Runtime_min  \
# 0   Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014          121
# 6   Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....  2016          128
# 16  Andrew Garfield, Sam Worthington, Luke Bracey,...  2016          139
# 18  Dev Patel, Nicole Kidman, Rooney Mara, Sunny P...  2016          118
# 36  Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014          169
#
#     Rating    Votes   Rev_M  Metascore  AvgRating  CustomRating
# 0      8.1   757074  333.13       76.0       7.85           8.1
# 6      8.3   258682  151.06       93.0       8.80           7.3
# 16     8.2   211760   67.12       71.0       7.65           8.2
# 18     8.1   102061   51.69       69.0       7.50           8.1
# 36     8.6  1047747  187.99       74.0       8.00           8.6

# %%
Or_df = df[(df['Rating']>8) | (df['Metascore']>80)]
Or_df.head()
# Out:
#     Rank                    Title                       Genre  \
# 0      1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 6      7               La La Land          Comedy,Drama,Music
# 13    14                    Moana  Animation,Adventure,Comedy
# 16    17            Hacksaw Ridge     Biography,Drama,History
# 18    19                     Lion             Biography,Drama
#
#                                           Description         Director  \
# 0   A group of intergalactic criminals are forced ...       James Gunn
# 6   A jazz pianist falls for an aspiring actress i...  Damien Chazelle
# 13  In Ancient Polynesia, when a terrible curse in...     Ron Clements
# 16  WWII American Army Medic Desmond T. Doss, who ...       Mel Gibson
# 18  A five-year-old Indian boy gets lost on the st...      Garth Davis
#
#                                                Actors  Year  Runtime_min  \
# 0   Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014          121
# 6   Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....  2016          128
# 13  Auli'i Cravalho, Dwayne Johnson, Rachel House,...  2016          107
# 16  Andrew Garfield, Sam Worthington, Luke Bracey,...  2016          139
# 18  Dev Patel, Nicole Kidman, Rooney Mara, Sunny P...  2016          118
#
#     Rating   Votes   Rev_M  Metascore  AvgRating  CustomRating
# 0      8.1  757074  333.13       76.0       7.85           8.1
# 6      8.3  258682  151.06       93.0       8.80           7.3
# 13     7.7  118151  248.75       81.0       7.90           6.7
# 16     8.2  211760   67.12       71.0       7.65           8.2
# 18     8.1  102061   51.69       69.0       7.50           8.1

# %%
# Multiple conditions: NOT - dataframe with all emovies rated greater than 8 or having a metascore more than 90 have to be excluded

Not_df = df[~((df['Rating']>8) | (df['Metascore']>80))]
Not_df.head()
# Out:
#    Rank           Title                     Genre  \
# 1     2      Prometheus  Adventure,Mystery,Sci-Fi
# 2     3           Split           Horror,Thriller
# 3     4            Sing   Animation,Comedy,Family
# 4     5   Suicide Squad  Action,Adventure,Fantasy
# 5     6  The Great Wall  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
# 5  European mercenaries searching for black powde...           Yimou Zhang
#
#                                               Actors  Year  Runtime_min  \
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012          124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016          117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016          108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016          123
# 5      Matt Damon, Tian Jing, Willem Dafoe, Andy Lau  2016          103
#
#    Rating   Votes   Rev_M  Metascore  AvgRating  CustomRating
# 1     7.0  485820  126.46       65.0       6.75           7.0
# 2     7.3  157606  138.12       62.0       6.75           8.3
# 3     7.2   60545  270.32       59.0       6.55           6.2
# 4     6.2  393727  325.02       40.0       5.10           6.2
# 5     6.1   56036   45.13       42.0       5.15           6.1

# %%
# Single condition: dataframe with all movies rated greater than 8
df_gt_8 = df[df['Rating']>8]

# Multiple conditions: AND - dataframe with all movies rated greater than 8 and having more than 100000 votes
And_df = df[(df['Rating']>8) & (df['Votes']>100000)]

# Multiple conditions: OR - dataframe with all movies rated greater than 8 or having a metascore more than 90
Or_df = df[(df['Rating']>8) | (df['Metascore']>80)]

# Multiple conditions: NOT - dataframe with all emovies rated greater than 8 or having a metascore more than 90 have to be excluded
Not_df = df[~((df['Rating']>8) | (df['Metascore']>80))]

# %% [markdown]
# ### Dará um erro

# %%
new_df = df[len(df['Title'].split(" "))>=4]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-42e467e7cf08> in <module>
# ----> 1 new_df = df[len(df['Title'].split(" "))>=4]
#
# ~\.conda\envs\teste\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
df['num_words_title'] = df.apply(lambda x : len(x['Title'].split(" ")),axis=1)
#simple filter on new column
new_df = df[df['num_words_title']>=4]
new_df.head()

# %% [markdown]
# ### ERRO

# %%
if length of title >=4 and distinct genres >=2:
    if Rating>Metascore/10:
        if year>2013:
    else:
        if year<2012

# %%
new_df = df[df.apply(lambda x : len(x['Title'].split(" "))>=4,axis=1)]
new_df.head()

# %%
df.groupby(['Year']).agg({'Rev_M':np.mean}).to_dict()['Rev_M']
# Out:
# {2006: 86.2966666666667,
#  2007: 87.8822448979592,
#  2008: 99.08274509803925,
#  2009: 112.60127659574471,
#  2010: 105.08157894736843,
#  2011: 87.61225806451614,
#  2012: 107.97328125000004,
#  2013: 87.12181818181814,
#  2014: 85.0787234042553,
#  2015: 78.35504424778763,
#  2016: 54.690975609756116}

# %%
year_revenue_dict = df.groupby(['Year']).agg({'Rev_M':np.mean}).to_dict()['Rev_M']
def bool_provider(revenue, year):
    return revenue<year_revenue_dict[year]
    
new_df = df[df.apply(lambda x : bool_provider(x['Rev_M'],x['Year']),axis=1)]

new_df.head()
# Out:
#     Rank               Title                       Genre  \
# 5      6      The Great Wall    Action,Adventure,Fantasy
# 8      9  The Lost City of Z  Action,Adventure,Biography
# 14    15            Colossal         Action,Comedy,Drama
# 18    19                Lion             Biography,Drama
# 20    21                Gold    Adventure,Drama,Thriller
#
#                                           Description         Director  \
# 5   European mercenaries searching for black powde...      Yimou Zhang
# 8   A true-life drama, centering on British explor...       James Gray
# 14  Gloria is an out-of-work party girl forced to ...  Nacho Vigalondo
# 18  A five-year-old Indian boy gets lost on the st...      Garth Davis
# 20  Kenny Wells, a prospector desperate for a luck...   Stephen Gaghan
#
#                                                Actors  Year  Runtime_min  \
# 5       Matt Damon, Tian Jing, Willem Dafoe, Andy Lau  2016          103
# 8   Charlie Hunnam, Robert Pattinson, Sienna Mille...  2016          141
# 14  Anne Hathaway, Jason Sudeikis, Austin Stowell,...  2016          109
# 18  Dev Patel, Nicole Kidman, Rooney Mara, Sunny P...  2016          118
# 20  Matthew McConaughey, Edgar Ramírez, Bryce Dall...  2016          120
#
#     Rating   Votes  Rev_M  Metascore  AvgRating  CustomRating
# 5      6.1   56036  45.13       42.0       5.15           6.1
# 8      7.1    7188   8.01       78.0       7.45           7.1
# 14     6.4    8612   2.87       70.0       6.70           5.4
# 18     8.1  102061  51.69       69.0       7.50           8.1
# 20     6.7   19053   7.22       49.0       5.80           7.7

# %%
df['Price'] = new_df['Year'].astype('int')
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# 2    Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3    In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4    A secret government agency recruits some of th...            David Ayer
# ..                                                 ...                   ...
# 995  A tight-knit team of rising investigators, alo...             Billy Ray
# 996  Three American college students studying abroa...              Eli Roth
# 997  Romantic sparks occur between two dance studen...            Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...        Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...      Barry Sonnenfeld
#
#                                                 Actors  Year  Runtime_min  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014          121
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012          124
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016          117
# 3    Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016          108
# 4    Will Smith, Jared Leto, Margot Robbie, Viola D...  2016          123
# ..                                                 ...   ...          ...
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015          111
# 996  Lauren German, Heather Matarazzo, Bijou Philli...  2007           94
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008           98
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014           93
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016           87
#
#      Rating   Votes   Rev_M  Metascore  AvgRating  CustomRating   Price
# 0       8.1  757074  333.13       76.0       7.85           8.1     NaN
# 1       7.0  485820  126.46       65.0       6.75           7.0     NaN
# 2       7.3  157606  138.12       62.0       6.75           8.3     NaN
# 3       7.2   60545  270.32       59.0       6.55           6.2     NaN
# 4       6.2  393727  325.02       40.0       5.10           6.2     NaN
# ..      ...     ...     ...        ...        ...           ...     ...
# 995     6.2   27585     NaN       45.0       5.35           6.2     NaN
# 996     5.5   73152   17.54       46.0       5.05           5.5  2007.0
# 997     6.2   70699   58.01       50.0       5.60           6.2  2008.0
# 998     5.6    4881     NaN       22.0       3.90           4.6     NaN
# 999     5.3   12435   19.64       11.0       3.20           4.3  2016.0
#
# [1000 rows x 15 columns]

# %%
df['Price'] = new_df['Year'].astype('str')

df['Price'] = df.apply(lambda x: int(x['Year'].replace('.', '')),axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-093ea4033e0a> in <module>
#       1 df['Price'] = new_df['Year'].astype('str')
#       2
# ----> 3 df['Price'] = df.apply(lambda x: int(x['Year'].replace('.', '')),axis=1)
#
# ~\.conda\envs\teste\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~\.conda\envs\teste\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\.conda\envs\teste\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     293
#     294             try:
# --> 295                 result = libreduction.compute_reduction(
#     296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-17-093ea4033e0a> in <lambda>(x)
#       1 df['Price'] = new_df['Year'].astype('str')
#       2
# ----> 3 df['Price'] = df.apply(lambda x: int(x['Year'].replace('.', '')),axis=1)
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
from tqdm import tqdm, tqdm_notebook
tqdm_notebook().pandas()
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# C:\Users\Vilquer\.conda\envs\teste\lib\site-packages\tqdm\_tqdm.py:544: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\.conda\envs\teste\lib\site-packages\tqdm\_tqdm.py in pandas(tclass, *targs, **tkwargs)
#     551             # pandas>=0.23.0
# --> 552             from pandas.core.groupby.groupby import DataFrameGroupBy, \
#     553                 SeriesGroupBy, GroupBy, PanelGroupBy
#
# ImportError: cannot import name 'DataFrameGroupBy' from 'pandas.core.groupby.groupby' (C:\Users\Vilquer\.conda\envs\teste\lib\site-packages\pandas\core\groupby\groupby.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-d6253f1a8a87> in <module>
#       1 from tqdm import tqdm, tqdm_notebook
# ----> 2 tqdm_notebook().pandas()
#
# ~\.conda\envs\teste\lib\site-packages\tqdm\_tqdm.py in pandas(tclass, *targs, **tkwargs)
#     553                 SeriesGroupBy, GroupBy, PanelGroupBy
#     554         except ImportError:
# --> 555             from pandas.core.groupby import DataFrameGroupBy, \
#     556                 SeriesGroupBy, GroupBy, PanelGroupBy
#     557
#
# ImportError: cannot import name 'PanelGroupBy' from 'pandas.core.groupby' (C:\Users\Vilquer\.conda\envs\teste\lib\site-packages\pandas\core\groupby\__init__.py)

# %%
new_df['rating_custom'] = df.progress_apply(lambda x: custom_rating(x['Genre'],x['Rating']),axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-5086f819090c> in <module>
# ----> 1 new_df['rating_custom'] = df.progress_apply(lambda x: custom_rating(x['Genre'],x['Rating']),axis=1)
#
# ~\.conda\envs\teste\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'progress_apply'

# %% [markdown]
# # precisa fazer um downgrade do pandas pra funcionar

# %%
import tqdm
from tqdm._tqdm_notebook import tqdm_notebook

df = pd.DataFrame(np.random.rand(10000),columns=['rand'])
tqdm_notebook.pandas('PROGRESS>>>')
df['result'] = df['rand'].progress_apply(lambda x:x**x)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\.conda\envs\teste\lib\site-packages\tqdm\_tqdm.py in pandas(tclass, *targs, **tkwargs)
#     551             # pandas>=0.23.0
# --> 552             from pandas.core.groupby.groupby import DataFrameGroupBy, \
#     553                 SeriesGroupBy, GroupBy, PanelGroupBy
#
# ImportError: cannot import name 'DataFrameGroupBy' from 'pandas.core.groupby.groupby' (C:\Users\Vilquer\.conda\envs\teste\lib\site-packages\pandas\core\groupby\groupby.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-1d94c7f67d2f> in <module>
#       3
#       4 df = pd.DataFrame(np.random.rand(10000),columns=['rand'])
# ----> 5 tqdm_notebook.pandas('PROGRESS>>>')
#       6 df['result'] = df['rand'].progress_apply(lambda x:x**x)
#
# ~\.conda\envs\teste\lib\site-packages\tqdm\_tqdm.py in pandas(tclass, *targs, **tkwargs)
#     553                 SeriesGroupBy, GroupBy, PanelGroupBy
#     554         except ImportError:
# --> 555             from pandas.core.groupby import DataFrameGroupBy, \
#     556                 SeriesGroupBy, GroupBy, PanelGroupBy
#     557
#
# ImportError: cannot import name 'PanelGroupBy' from 'pandas.core.groupby' (C:\Users\Vilquer\.conda\envs\teste\lib\site-packages\pandas\core\groupby\__init__.py)

# %%
from time import sleep
from tqdm import tqdm, tqdm_notebook

tqdm.pandas(tqdm_notebook)
_ = pd.DataFrame(np.random.randint(0, 100, (1,20))).progress_apply(lambda x: sleep(0.1))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\.conda\envs\teste\lib\site-packages\tqdm\_tqdm.py in pandas(tclass, *targs, **tkwargs)
#     551             # pandas>=0.23.0
# --> 552             from pandas.core.groupby.groupby import DataFrameGroupBy, \
#     553                 SeriesGroupBy, GroupBy, PanelGroupBy
#
# ImportError: cannot import name 'DataFrameGroupBy' from 'pandas.core.groupby.groupby' (C:\Users\Vilquer\.conda\envs\teste\lib\site-packages\pandas\core\groupby\groupby.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-d578eaf8a3cc> in <module>
#       2 from tqdm import tqdm, tqdm_notebook
#       3
# ----> 4 tqdm.pandas(tqdm_notebook)
#       5 _ = pd.DataFrame(np.random.randint(0, 100, (1,20))).progress_apply(lambda x: sleep(0.1))
#
# ~\.conda\envs\teste\lib\site-packages\tqdm\_tqdm.py in pandas(tclass, *targs, **tkwargs)
#     553                 SeriesGroupBy, GroupBy, PanelGroupBy
#     554         except ImportError:
# --> 555             from pandas.core.groupby import DataFrameGroupBy, \
#     556                 SeriesGroupBy, GroupBy, PanelGroupBy
#     557
#
# ImportError: cannot import name 'PanelGroupBy' from 'pandas.core.groupby' (C:\Users\Vilquer\.conda\envs\teste\lib\site-packages\pandas\core\groupby\__init__.py)
