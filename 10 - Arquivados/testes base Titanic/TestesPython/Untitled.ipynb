# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
test = pd.read_csv("test.csv")
train =  pd.read_csv("train.csv")
sample = pd.read_csv("gender_submission.csv")
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test = test.merge(sample, left_on='PassengerId', right_on='PassengerId')

# %%
df_all = pd.concat([train, test], sort=False, ignore_index=True)
df_all
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
# 1308      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     1309 non-null   int64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 122.8+ KB

# %%
df_all.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %% [markdown]
# ### Descrição
# ~~~
# Survived (Sobreviveu): 0 = Não, 1 = Sim
# Pclass (Classe): Classe de ingresso 1 = 1º, 2 = 2º, 3 = 3º
# Sex (Sexo): Sexo do passageiro
# Age (Idade): Idade em anos
# Sibsp: Quantidade de irmãos / cônjuges a bordo do Titanic
# Parch: Quantidade de pais / crianças a bordo do Titanic
# Ticket (Bilhete): Número do bilhete de embarque
# Fare (Tarifa): Tarifa paga pelo Passageiro
# Cabin (Cabine): Número de cabine
# Embarked (Embarque): Porto de Embarque (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# ~~~

# %%
df_all.columns = ['Id','sobreviveu', 'Classe', 'Nome', 'Sexo', 'Idade', 'QT_irmao_conjuge', 'Qt_pais_crianca', 'bilhete', 'Tarifa', 'Cabine', 'Embarque']

# %%
df_all.boxplot(column=['QT_irmao_conjuge','Qt_pais_crianca'])
# Out:
# <AxesSubplot:>

# %%
display(df_all[df_all['Qt_pais_crianca']>4].style.background_gradient(cmap='viridis', subset=['Qt_pais_crianca']))
display(df_all[df_all['QT_irmao_conjuge']> 4].style.background_gradient(cmap='viridis', subset=['QT_irmao_conjuge']))
# Out:
# <style  type="text/css" >
# #T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow0_col7,#T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow1_col7,#T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow2_col7,#T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow3_col7,#T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow5_col7,#T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow7_col7{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow4_col7,#T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow6_col7{
#             background-color:  #3b528b;
#             color:  #f1f1f1;
#         }#T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow8_col7,#T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow9_col7{
#             background-color:  #fde725;
#             color:  #000000;
#         }</style><table id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Id</th>        <th class="col_heading level0 col1" >sobreviveu</th>        <th class="col_heading level0 col2" >Classe</th>        <th class="col_heading level0 col3" >Nome</th>        <th class="col_heading level0 col4" >Sexo</th>        <th class="col_heading level0 col5" >Idade</th>        <th class="col_heading level0 col6" >QT_irmao_conjuge</th>        <th class="col_heading level0 col7" >Qt_pais_crianca</th>        <th class="col_heading level0 col8" >bilhete</th>        <th class="col_heading level0 col9" >Tarifa</th>        <th class="col_heading level0 col10" >Cabine</th>        <th class="col_heading level0 col11" >Embarque</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56dlevel0_row0" class="row_heading level0 row0" >13</th>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow0_col0" class="data row0 col0" >14</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow0_col2" class="data row0 col2" >3</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow0_col3" class="data row0 col3" >Andersson, Mr. Anders Johan</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow0_col4" class="data row0 col4" >male</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow0_col5" class="data row0 col5" >39.000000</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow0_col6" class="data row0 col6" >1</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow0_col7" class="data row0 col7" >5</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow0_col8" class="data row0 col8" >347082</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow0_col9" class="data row0 col9" >31.275000</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow0_col10" class="data row0 col10" >nan</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow0_col11" class="data row0 col11" >S</td>
#             </tr>
#             <tr>
#                         <th id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56dlevel0_row1" class="row_heading level0 row1" >25</th>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow1_col0" class="data row1 col0" >26</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow1_col1" class="data row1 col1" >1</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow1_col2" class="data row1 col2" >3</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow1_col3" class="data row1 col3" >Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow1_col4" class="data row1 col4" >female</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow1_col5" class="data row1 col5" >38.000000</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow1_col6" class="data row1 col6" >1</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow1_col7" class="data row1 col7" >5</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow1_col8" class="data row1 col8" >347077</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow1_col9" class="data row1 col9" >31.387500</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow1_col10" class="data row1 col10" >nan</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow1_col11" class="data row1 col11" >S</td>
#             </tr>
#             <tr>
#                         <th id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56dlevel0_row2" class="row_heading level0 row2" >610</th>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow2_col0" class="data row2 col0" >611</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow2_col1" class="data row2 col1" >0</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow2_col2" class="data row2 col2" >3</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow2_col3" class="data row2 col3" >Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow2_col4" class="data row2 col4" >female</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow2_col5" class="data row2 col5" >39.000000</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow2_col6" class="data row2 col6" >1</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow2_col7" class="data row2 col7" >5</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow2_col8" class="data row2 col8" >347082</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow2_col9" class="data row2 col9" >31.275000</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow2_col10" class="data row2 col10" >nan</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow2_col11" class="data row2 col11" >S</td>
#             </tr>
#             <tr>
#                         <th id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56dlevel0_row3" class="row_heading level0 row3" >638</th>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow3_col0" class="data row3 col0" >639</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow3_col1" class="data row3 col1" >0</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow3_col2" class="data row3 col2" >3</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow3_col3" class="data row3 col3" >Panula, Mrs. Juha (Maria Emilia Ojala)</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow3_col4" class="data row3 col4" >female</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow3_col5" class="data row3 col5" >41.000000</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow3_col6" class="data row3 col6" >0</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow3_col7" class="data row3 col7" >5</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow3_col8" class="data row3 col8" >3101295</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow3_col9" class="data row3 col9" >39.687500</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow3_col10" class="data row3 col10" >nan</td>
#                         <td id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56drow3_col11" class="data row3 col11" >S</td>
#             </tr>
#             <tr>
#                         <th id="T_e1314c7c_56cd_11eb_ab4d_7c8ae1d9d56dleve
# <style  type="text/css" >
# #T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow0_col6,#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow1_col6,#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow6_col6,#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow7_col6,#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow8_col6,#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow12_col6{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow2_col6,#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow3_col6,#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow4_col6,#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow5_col6,#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow9_col6,#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow10_col6,#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow11_col6,#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow13_col6,#T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow14_col6{
#             background-color:  #fde725;
#             color:  #000000;
#         }</style><table id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Id</th>        <th class="col_heading level0 col1" >sobreviveu</th>        <th class="col_heading level0 col2" >Classe</th>        <th class="col_heading level0 col3" >Nome</th>        <th class="col_heading level0 col4" >Sexo</th>        <th class="col_heading level0 col5" >Idade</th>        <th class="col_heading level0 col6" >QT_irmao_conjuge</th>        <th class="col_heading level0 col7" >Qt_pais_crianca</th>        <th class="col_heading level0 col8" >bilhete</th>        <th class="col_heading level0 col9" >Tarifa</th>        <th class="col_heading level0 col10" >Cabine</th>        <th class="col_heading level0 col11" >Embarque</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56dlevel0_row0" class="row_heading level0 row0" >59</th>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow0_col0" class="data row0 col0" >60</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow0_col2" class="data row0 col2" >3</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow0_col3" class="data row0 col3" >Goodwin, Master. William Frederick</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow0_col4" class="data row0 col4" >male</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow0_col5" class="data row0 col5" >11.000000</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow0_col6" class="data row0 col6" >5</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow0_col7" class="data row0 col7" >2</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow0_col8" class="data row0 col8" >CA 2144</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow0_col9" class="data row0 col9" >46.900000</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow0_col10" class="data row0 col10" >nan</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow0_col11" class="data row0 col11" >S</td>
#             </tr>
#             <tr>
#                         <th id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56dlevel0_row1" class="row_heading level0 row1" >71</th>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow1_col0" class="data row1 col0" >72</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow1_col1" class="data row1 col1" >0</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow1_col2" class="data row1 col2" >3</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow1_col3" class="data row1 col3" >Goodwin, Miss. Lillian Amy</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow1_col4" class="data row1 col4" >female</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow1_col5" class="data row1 col5" >16.000000</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow1_col6" class="data row1 col6" >5</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow1_col7" class="data row1 col7" >2</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow1_col8" class="data row1 col8" >CA 2144</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow1_col9" class="data row1 col9" >46.900000</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow1_col10" class="data row1 col10" >nan</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow1_col11" class="data row1 col11" >S</td>
#             </tr>
#             <tr>
#                         <th id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56dlevel0_row2" class="row_heading level0 row2" >159</th>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow2_col0" class="data row2 col0" >160</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow2_col1" class="data row2 col1" >0</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow2_col2" class="data row2 col2" >3</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow2_col3" class="data row2 col3" >Sage, Master. Thomas Henry</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow2_col4" class="data row2 col4" >male</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow2_col5" class="data row2 col5" >nan</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow2_col6" class="data row2 col6" >8</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow2_col7" class="data row2 col7" >2</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow2_col8" class="data row2 col8" >CA. 2343</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow2_col9" class="data row2 col9" >69.550000</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow2_col10" class="data row2 col10" >nan</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow2_col11" class="data row2 col11" >S</td>
#             </tr>
#             <tr>
#                         <th id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56dlevel0_row3" class="row_heading level0 row3" >180</th>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow3_col0" class="data row3 col0" >181</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow3_col1" class="data row3 col1" >0</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow3_col2" class="data row3 col2" >3</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow3_col3" class="data row3 col3" >Sage, Miss. Constance Gladys</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow3_col4" class="data row3 col4" >female</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow3_col5" class="data row3 col5" >nan</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow3_col6" class="data row3 col6" >8</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow3_col7" class="data row3 col7" >2</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow3_col8" class="data row3 col8" >CA. 2343</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow3_col9" class="data row3 col9" >69.550000</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow3_col10" class="data row3 col10" >nan</td>
#                         <td id="T_e1347f81_56cd_11eb_9300_7c8ae1d9d56drow3_col11" class="data row3 col11" >S</td>

# %%
df_all.boxplot(column='Idade')
# Out:
# <AxesSubplot:>

# %%
df_all[df_all['Idade']> 70].style.background_gradient(cmap='viridis', subset=['Idade'])
# Out:
# <style  type="text/css" >
# #T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow0_col5,#T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow2_col5{
#             background-color:  #481467;
#             color:  #f1f1f1;
#         }#T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow1_col5{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow3_col5{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow4_col5{
#             background-color:  #2d718e;
#             color:  #f1f1f1;
#         }#T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow5_col5{
#             background-color:  #20a386;
#             color:  #000000;
#         }</style><table id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Id</th>        <th class="col_heading level0 col1" >sobreviveu</th>        <th class="col_heading level0 col2" >Classe</th>        <th class="col_heading level0 col3" >Nome</th>        <th class="col_heading level0 col4" >Sexo</th>        <th class="col_heading level0 col5" >Idade</th>        <th class="col_heading level0 col6" >QT_irmao_conjuge</th>        <th class="col_heading level0 col7" >Qt_pais_crianca</th>        <th class="col_heading level0 col8" >bilhete</th>        <th class="col_heading level0 col9" >Tarifa</th>        <th class="col_heading level0 col10" >Cabine</th>        <th class="col_heading level0 col11" >Embarque</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56dlevel0_row0" class="row_heading level0 row0" >96</th>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow0_col0" class="data row0 col0" >97</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow0_col2" class="data row0 col2" >1</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow0_col3" class="data row0 col3" >Goldschmidt, Mr. George B</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow0_col4" class="data row0 col4" >male</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow0_col5" class="data row0 col5" >71.000000</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow0_col6" class="data row0 col6" >0</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow0_col7" class="data row0 col7" >0</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow0_col8" class="data row0 col8" >PC 17754</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow0_col9" class="data row0 col9" >34.654200</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow0_col10" class="data row0 col10" >A5</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow0_col11" class="data row0 col11" >C</td>
#             </tr>
#             <tr>
#                         <th id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56dlevel0_row1" class="row_heading level0 row1" >116</th>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow1_col0" class="data row1 col0" >117</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow1_col1" class="data row1 col1" >0</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow1_col2" class="data row1 col2" >3</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow1_col3" class="data row1 col3" >Connors, Mr. Patrick</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow1_col4" class="data row1 col4" >male</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow1_col5" class="data row1 col5" >70.500000</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow1_col6" class="data row1 col6" >0</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow1_col7" class="data row1 col7" >0</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow1_col8" class="data row1 col8" >370369</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow1_col9" class="data row1 col9" >7.750000</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow1_col10" class="data row1 col10" >nan</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow1_col11" class="data row1 col11" >Q</td>
#             </tr>
#             <tr>
#                         <th id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56dlevel0_row2" class="row_heading level0 row2" >493</th>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow2_col0" class="data row2 col0" >494</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow2_col1" class="data row2 col1" >0</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow2_col3" class="data row2 col3" >Artagaveytia, Mr. Ramon</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow2_col4" class="data row2 col4" >male</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow2_col5" class="data row2 col5" >71.000000</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow2_col6" class="data row2 col6" >0</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow2_col7" class="data row2 col7" >0</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow2_col8" class="data row2 col8" >PC 17609</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow2_col9" class="data row2 col9" >49.504200</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow2_col10" class="data row2 col10" >nan</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow2_col11" class="data row2 col11" >C</td>
#             </tr>
#             <tr>
#                         <th id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56dlevel0_row3" class="row_heading level0 row3" >630</th>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow3_col0" class="data row3 col0" >631</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow3_col1" class="data row3 col1" >1</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow3_col2" class="data row3 col2" >1</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow3_col3" class="data row3 col3" >Barkworth, Mr. Algernon Henry Wilson</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow3_col4" class="data row3 col4" >male</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow3_col5" class="data row3 col5" >80.000000</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow3_col6" class="data row3 col6" >0</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow3_col7" class="data row3 col7" >0</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow3_col8" class="data row3 col8" >27042</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow3_col9" class="data row3 col9" >30.000000</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow3_col10" class="data row3 col10" >A23</td>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56drow3_col11" class="data row3 col11" >S</td>
#             </tr>
#             <tr>
#                         <th id="T_e16812af_56cd_11eb_828c_7c8ae1d9d56dlevel0_row4" class="row_heading level0 row4" >851</th>
#                         <td id="T_e16812af_56cd_11eb_828c_7c8ae1d9

# %%
sns.countplot(x='sobreviveu', data=df_all)
# Out:
# <AxesSubplot:xlabel='sobreviveu', ylabel='count'>

# %%
sns.countplot(x='sobreviveu', hue='Sexo', data=df_all)
# Out:
# <AxesSubplot:xlabel='sobreviveu', ylabel='count'>

# %%
sns.countplot(x='Classe', data=df_all)
# Out:
# <AxesSubplot:xlabel='Classe', ylabel='count'>

# %%
sns.countplot(x='sobreviveu', hue='Classe', data=df_all)
# Out:
# <AxesSubplot:xlabel='sobreviveu', ylabel='count'>

# %%
df_all['Embarque'].mode() # O mode é o valor que aparece mais
# Out:
# 0    S
# dtype: object

# %%
df_all.isnull().sum()
# Out:
# Id                     0
# sobreviveu             0
# Classe                 0
# Nome                   0
# Sexo                   0
# Idade                263
# QT_irmao_conjuge       0
# Qt_pais_crianca        0
# bilhete                0
# Tarifa                 1
# Cabine              1014
# Embarque               2
# dtype: int64

# %%
df_all[df_all['Embarque'].isna()]
# Out:
#       Id  sobreviveu  Classe                                       Nome  \
# 61    62           1       1                        Icard, Miss. Amelie
# 829  830           1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#        Sexo  Idade  QT_irmao_conjuge  Qt_pais_crianca bilhete  Tarifa Cabine  \
# 61   female   38.0                 0                0  113572    80.0    B28
# 829  female   62.0                 0                0  113572    80.0    B28
#
#     Embarque
# 61       NaN
# 829      NaN

# %%
df_all[df_all['bilhete'] == '113572' ]
# Out:
#       Id  sobreviveu  Classe                                       Nome  \
# 61    62           1       1                        Icard, Miss. Amelie
# 829  830           1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#        Sexo  Idade  QT_irmao_conjuge  Qt_pais_crianca bilhete  Tarifa Cabine  \
# 61   female   38.0                 0                0  113572    80.0    B28
# 829  female   62.0                 0                0  113572    80.0    B28
#
#     Embarque
# 61       NaN
# 829      NaN

# %%
sns.countplot(x='Classe', hue='Embarque', data=df_all)
# Out:
# <AxesSubplot:xlabel='Classe', ylabel='count'>

# %%
df_all['Embarque'] = df_all['Embarque'].fillna(df_all['Embarque'].mode()[0])

# %%
df_all[df_all['bilhete'] == '113572' ]
# Out:
#       Id  sobreviveu  Classe                                       Nome  \
# 61    62           1       1                        Icard, Miss. Amelie
# 829  830           1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#        Sexo  Idade  QT_irmao_conjuge  Qt_pais_crianca bilhete  Tarifa Cabine  \
# 61   female   38.0                 0                0  113572    80.0    B28
# 829  female   62.0                 0                0  113572    80.0    B28
#
#     Embarque
# 61         S
# 829        S

# %%
df_all['Cabine'] = df_all['Cabine'].fillna('X-Desconhecido') # sinalisar desonhecido

# %%
df_all[df_all['Tarifa'].isna()]
# Out:
#         Id  sobreviveu  Classe                Nome  Sexo  Idade  \
# 1043  1044           0       3  Storey, Mr. Thomas  male   60.5
#
#       QT_irmao_conjuge  Qt_pais_crianca bilhete  Tarifa          Cabine  \
# 1043                 0                0    3701     NaN  X-Desconhecido
#
#      Embarque
# 1043        S

# %%
df_all[df_all['Classe'] == 3].Tarifa.mean()
# Out:
# 13.302888700564973

# %%
df_all['Tarifa'] = df_all['Tarifa'].fillna(df_all[df_all['Classe'] == 3].Tarifa.mean()) # sinalisar desonhecido

# %%
df_all[df_all['Id'] == 1044]
# Out:
#         Id  sobreviveu  Classe                Nome  Sexo  Idade  \
# 1043  1044           0       3  Storey, Mr. Thomas  male   60.5
#
#       QT_irmao_conjuge  Qt_pais_crianca bilhete     Tarifa          Cabine  \
# 1043                 0                0    3701  13.302889  X-Desconhecido
#
#      Embarque
# 1043        S

# %%
df_all.isnull().sum()
# Out:
# Id                    0
# sobreviveu            0
# Classe                0
# Nome                  0
# Sexo                  0
# Idade               263
# QT_irmao_conjuge      0
# Qt_pais_crianca       0
# bilhete               0
# Tarifa                0
# Cabine                0
# Embarque              0
# dtype: int64

# %%
df_all.groupby(['Sexo', 'Classe'])['Idade']

# %%
#Idade é preenchido com a mediana das idades por Sexo e por Classe
df_all['Idade'] = df_all.groupby(['Sexo', 'Classe'])['Idade'].apply(lambda x: x.fillna(x.median()))

# %%
df_all
# Out:
#         Id  sobreviveu  Classe  \
# 0        1           0       3
# 1        2           1       1
# 2        3           1       3
# 3        4           1       1
# 4        5           0       3
# ...    ...         ...     ...
# 1304  1305           0       3
# 1305  1306           1       1
# 1306  1307           0       3
# 1307  1308           0       3
# 1308  1309           0       3
#
#                                                    Nome    Sexo  Idade  \
# 0                               Braund, Mr. Owen Harris    male   22.0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                                Heikkinen, Miss. Laina  female   26.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                              Allen, Mr. William Henry    male   35.0
# ...                                                 ...     ...    ...
# 1304                                 Spector, Mr. Woolf    male   25.0
# 1305                       Oliva y Ocana, Dona. Fermina  female   39.0
# 1306                       Saether, Mr. Simon Sivertsen    male   38.5
# 1307                                Ware, Mr. Frederick    male   25.0
# 1308                           Peter, Master. Michael J    male   25.0
#
#       QT_irmao_conjuge  Qt_pais_crianca             bilhete    Tarifa  \
# 0                    1                0           A/5 21171    7.2500
# 1                    1                0            PC 17599   71.2833
# 2                    0                0    STON/O2. 3101282    7.9250
# 3                    1                0              113803   53.1000
# 4                    0                0              373450    8.0500
# ...                ...              ...                 ...       ...
# 1304                 0                0           A.5. 3236    8.0500
# 1305                 0                0            PC 17758  108.9000
# 1306                 0                0  SOTON/O.Q. 3101262    7.2500
# 1307                 0                0              359309    8.0500
# 1308                 1                1                2668   22.3583
#
#               Cabine Embarque
# 0     X-Desconhecido        S
# 1                C85        C
# 2     X-Desconhecido        S
# 3               C123        S
# 4     X-Desconhecido        S
# ...              ...      ...
# 1304  X-Desconhecido        S
# 1305            C105        C
# 1306  X-Desconhecido        S
# 1307  X-Desconhecido        S
# 1308  X-Desconhecido        C
#
# [1309 rows x 12 columns]

# %%
df_all.isnull().sum()
# Out:
# Id                  0
# sobreviveu          0
# Classe              0
# Nome                0
# Sexo                0
# Idade               0
# QT_irmao_conjuge    0
# Qt_pais_crianca     0
# bilhete             0
# Tarifa              0
# Cabine              0
# Embarque            0
# dtype: int64

# %%
df_all['Cabine'] = df_all['Cabine'].apply(lambda x: x[0])

idx = df_all[df_all['Cabine'] == 'T'].index
df_all.loc[idx, 'Cabine'] = 'A'

df_all['Cabine'] = df_all['Cabine'].replace(['A', 'B', 'C'], 'ABC')
df_all['Cabine'] = df_all['Cabine'].replace(['D', 'E'], 'DE')
df_all['Cabine'] = df_all['Cabine'].replace(['F', 'G'], 'FG')

# %%
df_all
# Out:
#         Id  sobreviveu  Classe  \
# 0        1           0       3
# 1        2           1       1
# 2        3           1       3
# 3        4           1       1
# 4        5           0       3
# ...    ...         ...     ...
# 1304  1305           0       3
# 1305  1306           1       1
# 1306  1307           0       3
# 1307  1308           0       3
# 1308  1309           0       3
#
#                                                    Nome    Sexo  Idade  \
# 0                               Braund, Mr. Owen Harris    male   22.0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                                Heikkinen, Miss. Laina  female   26.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                              Allen, Mr. William Henry    male   35.0
# ...                                                 ...     ...    ...
# 1304                                 Spector, Mr. Woolf    male   25.0
# 1305                       Oliva y Ocana, Dona. Fermina  female   39.0
# 1306                       Saether, Mr. Simon Sivertsen    male   38.5
# 1307                                Ware, Mr. Frederick    male   25.0
# 1308                           Peter, Master. Michael J    male   25.0
#
#       QT_irmao_conjuge  Qt_pais_crianca             bilhete    Tarifa Cabine  \
# 0                    1                0           A/5 21171    7.2500      X
# 1                    1                0            PC 17599   71.2833    ABC
# 2                    0                0    STON/O2. 3101282    7.9250      X
# 3                    1                0              113803   53.1000    ABC
# 4                    0                0              373450    8.0500      X
# ...                ...              ...                 ...       ...    ...
# 1304                 0                0           A.5. 3236    8.0500      X
# 1305                 0                0            PC 17758  108.9000    ABC
# 1306                 0                0  SOTON/O.Q. 3101262    7.2500      X
# 1307                 0                0              359309    8.0500      X
# 1308                 1                1                2668   22.3583      X
#
#      Embarque
# 0           S
# 1           C
# 2           S
# 3           S
# 4           S
# ...       ...
# 1304        S
# 1305        C
# 1306        S
# 1307        S
# 1308        C
#
# [1309 rows x 12 columns]

# %%
sns.catplot(x='sobreviveu', hue='Cabine', col='Classe',kind="count", data=df_all)

# %%
names = df_all['Nome'].str.split(',')
names = names.apply(lambda x: x[1]).str.split(" ")
names = names.apply(lambda x: x[1])
df_all['Titulo'] = names

df_all["Titulo"] = df_all["Titulo"].replace(to_replace=["Major." ,"Col.","Capt.","the","Don.",
                                                      "Jonkheer.","Lady.","Sir.", "Dona.",
                                                     "Rev.", "Dr."], value="Noble") 
df_all["Titulo"] = df_all["Titulo"].replace(to_replace=["Mlle.","Ms."],value="Miss.") 
df_all["Titulo"] = df_all["Titulo"].replace(to_replace=["Mme."], value="Mrs.") 

df_all["Titulo"].value_counts()
# Out:
# Mr.        757
# Miss.      264
# Mrs.       198
# Master.     61
# Noble       29
# Name: Titulo, dtype: int64

# %%
surnames = df_all['Nome'].str.split(',')
surnames = surnames.map(lambda x: x[0])
df_all['Surname'] = surnames

# %% [markdown]
# ~~~
# Crie novos recursos
# Ticket_frequency para a contagem de cada ticket
# Família que é a união de SibSp + Parch + 1 (a própria pessoa)
# A família é mapeada por tamanho (sozinha, pequena, média e grande)
# O FareBin mapeia a tarifa em 4 intervalos
# O AgeBin mapeia a Idade em 5 intervalos
#
# ~~~

# %%
df_all['Ticket_Frequency'] = df_all.groupby('bilhete')['bilhete'].transform('count')

df_all['Familia'] = df_all['QT_irmao_conjuge'] + df_all['Qt_pais_crianca'] + 1

family_map = {1: 'Alone', 2: 'Small', 3: 'Small', 4: 'Small', 5: 'Medium', 6: 'Medium', 7: 'Large', 8: 'Large', 11: 'Large'}
df_all['Familia'] = df_all['Familia'].map(family_map)

df_all['FareBin'] = pd.qcut(df_all['Tarifa'], 4)

df_all['AgeBin'] = pd.cut(df_all['Idade'].astype(int), 5)

# %%
df_all
# Out:
#         Id  sobreviveu  Classe  \
# 0        1           0       3
# 1        2           1       1
# 2        3           1       3
# 3        4           1       1
# 4        5           0       3
# ...    ...         ...     ...
# 1304  1305           0       3
# 1305  1306           1       1
# 1306  1307           0       3
# 1307  1308           0       3
# 1308  1309           0       3
#
#                                                    Nome    Sexo  Idade  \
# 0                               Braund, Mr. Owen Harris    male   22.0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                                Heikkinen, Miss. Laina  female   26.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                              Allen, Mr. William Henry    male   35.0
# ...                                                 ...     ...    ...
# 1304                                 Spector, Mr. Woolf    male   25.0
# 1305                       Oliva y Ocana, Dona. Fermina  female   39.0
# 1306                       Saether, Mr. Simon Sivertsen    male   38.5
# 1307                                Ware, Mr. Frederick    male   25.0
# 1308                           Peter, Master. Michael J    male   25.0
#
#       QT_irmao_conjuge  Qt_pais_crianca             bilhete    Tarifa Cabine  \
# 0                    1                0           A/5 21171    7.2500      X
# 1                    1                0            PC 17599   71.2833    ABC
# 2                    0                0    STON/O2. 3101282    7.9250      X
# 3                    1                0              113803   53.1000    ABC
# 4                    0                0              373450    8.0500      X
# ...                ...              ...                 ...       ...    ...
# 1304                 0                0           A.5. 3236    8.0500      X
# 1305                 0                0            PC 17758  108.9000    ABC
# 1306                 0                0  SOTON/O.Q. 3101262    7.2500      X
# 1307                 0                0              359309    8.0500      X
# 1308                 1                1                2668   22.3583      X
#
#      Embarque   Titulo        Surname  Ticket_Frequency Familia  \
# 0           S      Mr.         Braund                 1   Small
# 1           C     Mrs.        Cumings                 2   Small
# 2           S    Miss.      Heikkinen                 1   Alone
# 3           S     Mrs.       Futrelle                 2   Small
# 4           S      Mr.          Allen                 1   Alone
# ...       ...      ...            ...               ...     ...
# 1304        S      Mr.        Spector                 1   Alone
# 1305        C    Noble  Oliva y Ocana                 3   Alone
# 1306        S      Mr.        Saether                 1   Alone
# 1307        S      Mr.           Ware                 1   Alone
# 1308        C  Master.          Peter                 3   Small
#
#                 FareBin        AgeBin
# 0       (-0.001, 7.896]  (16.0, 32.0]
# 1     (31.275, 512.329]  (32.0, 48.0]
# 2       (7.896, 14.454]  (16.0, 32.0]
# 3     (31.275, 512.329]  (32.0, 48.0]
# 4       (7.896, 14.454]  (32.0, 48.0]
# ...                 ...           ...
# 1304    (7.896, 14.454]  (16.0, 32.0]
# 1305  (31.275, 512.329]  (32.0, 48.0]
# 1306    (-0.001, 7.896]  (32.0, 48.0]
# 1307    (7.896, 14.454]  (16.0, 32.0]
# 1308   (14.454, 31.275]  (16.0, 32.0]
#
# [1309 rows x 18 columns]

# %%
df_all = df_all.drop(['SibSp','Parch','Fare','Age','Name','Ticket','PassengerId'], axis=1)

# df_all["Sex"], _ = pd.factorize(df_all["Sex"], sort=True)
df_all["Embarked"], _ = pd.factorize(df_all["Embarked"], sort=True)
df_all["Title"], _ = pd.factorize(df_all["Title"], sort=True)
df_all["Cabin"], _ = pd.factorize(df_all["Cabin"], sort=True)
df_all["AgeBin"], _ = pd.factorize(df_all["AgeBin"], sort=True)
df_all["FareBin"], _ = pd.factorize(df_all["FareBin"], sort=True)
df_all["Family"], _ = pd.factorize(df_all["Family"], sort=True)
df_all["Surname"], _ = pd.factorize(df_all["Surname"], sort=True)

df_all = pd.get_dummies(df_all) #Sex
df_all.head()
