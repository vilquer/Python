# %%
# %config IPCompleter.greedy = True

# %%
d =  {"directed": True, "multigraph": False, "graph": {}, "nodes": [{"nome": "CIA DO SABOR", "tipo_pessoa": 1, "nivel": 0, "cnpj": "08613854000155", "matriz_filial": "1", "razao_social": "TF PORTAL & CIA LTDA", "nome_fantasia": "CIA DO SABOR", "situacao": "02", "data_situacao": "20061219", "motivo_situacao": "00", "nm_cidade_exterior": "", "cod_pais": "", "nome_pais": "", "cod_nat_juridica": "2062", "data_inicio_ativ": "20061219", "cnae_fiscal": "5611203", "tipo_logradouro": "AVENIDA", "logradouro": "NESTOR DE MOURA JARDIM", "numero": "81", "complemento": "LJ 01", "bairro": "SALGADO FILHO", "cep": "94020160", "uf": "RS", "cod_municipio": "8683", "municipio": "GRAVATAI", "ddd_1": "51", "telefone_1": "34969109", "ddd_2": "", "telefone_2": "", "ddd_fax": "", "num_fax": "", "email": "", "qualif_resp": "49", "capital_social": 800000.0, "porte": "01", "opc_simples": "5", "data_opc_simples": "20190101", "data_exc_simples": "", "opc_mei": "N", "sit_especial": "", "data_sit_especial": "", "id": "08613854000155"}, {"nome": "MARCIO FERREIRA DA SILVA", "tipo_pessoa": 2, "nivel": 1, "cpf": "***327330**", "id": "***327330**MARCIO FERREIRA DA SILVA"}, {"nome": "TAUANA PORTAL DA SILVA", "tipo_pessoa": 2, "nivel": 1, "cpf": "***662170**", "id": "***662170**TAUANA PORTAL DA SILVA"}, {"nome": "TAUANA PORTAL DA SILVA & CIA LTDA", "tipo_pessoa": 1, "nivel": 2, "cnpj": "28139778000103", "matriz_filial": "1", "razao_social": "TAUANA PORTAL DA SILVA & CIA LTDA", "nome_fantasia": "", "situacao": "02", "data_situacao": "20170706", "motivo_situacao": "00", "nm_cidade_exterior": "", "cod_pais": "", "nome_pais": "", "cod_nat_juridica": "2062", "data_inicio_ativ": "20170706", "cnae_fiscal": "5611203", "tipo_logradouro": "AVENIDA", "logradouro": "GENERAL FLORES DA CUNHA", "numero": "1115", "complemento": "LOJA  101", "bairro": "VILA VERANOPOLIS", "cep": "94910001", "uf": "RS", "cod_municipio": "8561", "municipio": "CACHOEIRINHA", "ddd_1": "51", "telefone_1": "34882844", "ddd_2": "", "telefone_2": "", "ddd_fax": "", "num_fax": "", "email": "WACONTABILRS@IG.COM.BR", "qualif_resp": "49", "capital_social": 1000000.0, "porte": "01", "opc_simples": "5", "data_opc_simples": "20170706", "data_exc_simples": "", "opc_mei": "N", "sit_especial": "", "data_sit_especial": "", "id": "28139778000103"}, {"nome": "ANDERSON RENATO MONTI RODRIGUES", "tipo_pessoa": 2, "nivel": 3, "cpf": "***405540**", "id": "***405540**ANDERSON RENATO MONTI RODRIGUES"}, {"nome": "MARCIO PIZZARIA", "tipo_pessoa": 1, "nivel": 2, "cnpj": "33346524000198", "matriz_filial": "1", "razao_social": "PORTAL & PORTAL COMERCIO VAREJISTA DE LANCHES E PIZZAS LTDA.", "nome_fantasia": "MARCIO PIZZARIA", "situacao": "02", "data_situacao": "20190412", "motivo_situacao": "00", "nm_cidade_exterior": "", "cod_pais": "", "nome_pais": "", "cod_nat_juridica": "2062", "data_inicio_ativ": "20190412", "cnae_fiscal": "5611203", "tipo_logradouro": "RUA", "logradouro": "PAULO MACIEL DE MORAES", "numero": "1009", "complemento": "", "bairro": "CENTRO", "cep": "95500000", "uf": "RS", "cod_municipio": "8855", "municipio": "SANTO ANTONIO DA PATRULHA", "ddd_1": "51", "telefone_1": "36625422", "ddd_2": "", "telefone_2": "", "ddd_fax": "", "num_fax": "", "email": "ANDERSONBELUSSO@HOTMAIL.COM", "qualif_resp": "49", "capital_social": 10000000.0, "porte": "01", "opc_simples": "5", "data_opc_simples": "20190412", "data_exc_simples": "", "opc_mei": "N", "sit_especial": "", "data_sit_especial": "", "id": "33346524000198"}, {"nome": "KARINE FRAGA PORTAL", "tipo_pessoa": 2, "nivel": 3, "cpf": "***209630**", "id": "***209630**KARINE FRAGA PORTAL"}], "links": [{"tipo": "socio", "cod_qualificacao": "49", "qualificacao": "S\u00f3cio-Administrador", "data_entrada": "20100802", "source": "***327330**MARCIO FERREIRA DA SILVA", "target": "08613854000155"}, {"tipo": "socio", "cod_qualificacao": "49", "qualificacao": "S\u00f3cio-Administrador", "data_entrada": "20170706", "source": "***662170**TAUANA PORTAL DA SILVA", "target": "28139778000103"}, {"tipo": "socio", "cod_qualificacao": "22", "qualificacao": "S\u00f3cio", "data_entrada": "20190412", "source": "***662170**TAUANA PORTAL DA SILVA", "target": "33346524000198"}, {"tipo": "socio", "cod_qualificacao": "49", "qualificacao": "S\u00f3cio-Administrador", "data_entrada": "20180509", "source": "***662170**TAUANA PORTAL DA SILVA", "target": "08613854000155"}, {"tipo": "socio", "cod_qualificacao": "22", "qualificacao": "S\u00f3cio", "data_entrada": "20170706", "source": "***405540**ANDERSON RENATO MONTI RODRIGUES", "target": "28139778000103"}, {"tipo": "socio", "cod_qualificacao": "49", "qualificacao": "S\u00f3cio-Administrador", "data_entrada": "20190412", "source": "***209630**KARINE FRAGA PORTAL", "target": "33346524000198"}]}
d
# Out:
# {'directed': True,
#  'multigraph': False,
#  'graph': {},
#  'nodes': [{'nome': 'CIA DO SABOR',
#    'tipo_pessoa': 1,
#    'nivel': 0,
#    'cnpj': '08613854000155',
#    'matriz_filial': '1',
#    'razao_social': 'TF PORTAL & CIA LTDA',
#    'nome_fantasia': 'CIA DO SABOR',
#    'situacao': '02',
#    'data_situacao': '20061219',
#    'motivo_situacao': '00',
#    'nm_cidade_exterior': '',
#    'cod_pais': '',
#    'nome_pais': '',
#    'cod_nat_juridica': '2062',
#    'data_inicio_ativ': '20061219',
#    'cnae_fiscal': '5611203',
#    'tipo_logradouro': 'AVENIDA',
#    'logradouro': 'NESTOR DE MOURA JARDIM',
#    'numero': '81',
#    'complemento': 'LJ 01',
#    'bairro': 'SALGADO FILHO',
#    'cep': '94020160',
#    'uf': 'RS',
#    'cod_municipio': '8683',
#    'municipio': 'GRAVATAI',
#    'ddd_1': '51',
#    'telefone_1': '34969109',
#    'ddd_2': '',
#    'telefone_2': '',
#    'ddd_fax': '',
#    'num_fax': '',
#    'email': '',
#    'qualif_resp': '49',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame([d], columns=d.keys())
df
# Out:
#    directed  multigraph graph  \
# 0      True       False    {}
#
#                                                nodes  \
# 0  [{'nome': 'CIA DO SABOR', 'tipo_pessoa': 1, 'n...
#
#                                                links
# 0  [{'tipo': 'socio', 'cod_qualificacao': '49', '...

# %%
df['nodes']
# Out:
# 0    [{'nome': 'CIA DO SABOR', 'tipo_pessoa': 1, 'n...
# Name: nodes, dtype: object

# %%
df['links']
# Out:
# 0    [{'tipo': 'socio', 'cod_qualificacao': '49', '...
# Name: links, dtype: object

# %%
import timeit
df_node = pd.DataFrame().append(d['nodes'], ignore_index=True)
df_node
# Out:
# UsageError: Line magic function `%timeit(df_node)` not found.

# %%
df_links = pd.DataFrame().append(d['links'], ignore_index=True)
df_links
# Out:
#     tipo cod_qualificacao         qualificacao data_entrada  \
# 0  socio               49  Sócio-Administrador     20100802
# 1  socio               49  Sócio-Administrador     20170706
# 2  socio               22                Sócio     20190412
# 3  socio               49  Sócio-Administrador     20180509
# 4  socio               22                Sócio     20170706
# 5  socio               49  Sócio-Administrador     20190412
#
#                                        source          target
# 0         ***327330**MARCIO FERREIRA DA SILVA  08613854000155
# 1           ***662170**TAUANA PORTAL DA SILVA  28139778000103
# 2           ***662170**TAUANA PORTAL DA SILVA  33346524000198
# 3           ***662170**TAUANA PORTAL DA SILVA  08613854000155
# 4  ***405540**ANDERSON RENATO MONTI RODRIGUES  28139778000103
# 5              ***209630**KARINE FRAGA PORTAL  33346524000198
